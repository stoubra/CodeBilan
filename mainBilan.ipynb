# %%
from Bilan import menuBilan
menuBilan()
# Out:
# [1] Chambre (Piece)
# [2] Appartement (Etage)
# [3] Immeuble (Maison)
# [4] Quiter
# Entrer votre choix : 1
# [1] Juste le plafon
# [2] juste les murs
# [3] La piece entier
# [4] affiche piece
# [5] reduction prix plafon
# [6] reduction prix mur
# [7] Quiter
# Entrer votre choix : 3
# Nom client : said
# Prenom client : toubra
# Adresse client : 1 rue de la concorde
# Code Postale client : 68000
# Ville client : Colmar
# Nom de la piece : sale de bain
# Longuer Grand Mur : 4
# Longuer Petit Mur : 3
# Hauteur Mur : 2.5
# Desciption du travail à faire pour le mur :
# Pinture normal
# Prix mur : 20
# Desciption du travail à faire pour le plafon :
# painture normal
# Prix plafon : 23
#
# [1] Juste le plafon
# [2] juste les murs
# [3] La piece entier
# [4] affiche piece
# [5] reduction prix plafon
# [6] reduction prix mur
# [7] Quiter
# Entrer votre choix : 4
# said
# toubra
# 1 rue de la concorde
# 68000   Colmar
# Nom de la piece :  sale de bain
# Longuer Grand Mur :  4.0
# ...

# %%
menuBilan()
# Out:
# [1] Chambre (Piece)
# [2] Appartement (Etage)
# [3] Immeuble (Maison)
# [4] Quiter
# Entrer votre choix : 5
# Erreur donner un autre nombre entre 1 et 5
#
# [1] Chambre (Piece)
# [2] Appartement (Etage)
# [3] Immeuble (Maison)
# [4] Quiter
# Entrer votre choix : 5
# Erreur donner un autre nombre entre 1 et 5
#
# [1] Chambre (Piece)
# [2] Appartement (Etage)
# [3] Immeuble (Maison)
# [4] Quiter
# Entrer votre choix : 2
# [1] sesie Appartement
# [2] affiche Appartement
# [3] Supprime Piece
# [4] Ajoute Piece
# [5] Quiter
# Entrer votre choix : 1
# Nom client : kihdz
# Prenom client : kinqd
# Adresse client : ggujdkif
# Code Postale client : 46352
# Ville client : jhki
# nombre de piece : 2
# Hauteur de l'appartement : 2.5
# Nom de la piece : salon
# Longuer Grand Mur : 4
# Longuer Petit Mur : 3.5
# Desciption du travail à faire pour le mur :
# vujkun
# Prix mur : 20
# Desciption du travail à faire pour le plafon :
# sdujykil
# Prix plafon : 23
# Nom de la piece : nnfzs
# ...
